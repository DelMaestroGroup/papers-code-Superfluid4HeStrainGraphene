# %% [markdown]
# ## Download QMC Data
#
# The raw (unprocessed) QMC data can be found online at:
#
# [![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.7271852.svg)](https://doi.org/10.5281/zenodo.7271852)
#
#
# While the processed/reduced data files necessary for producing all plots are included in the repository at `../data` run the code below to download the data for local processing.
#
# Requires installation of the [zenodo_get](https://github.com/dvolgyes/zenodo_get/) package.

# %%
qmc_data_dir = '../data/QMC/'
# !zenodo_get --doi=10.5281/zenodo.7271852 --output-dir={qmc_data_dir}
#!tar -xjf {qmc_data_dir}/QMC_raw_data.tar.bz2 -C {qmc_data_dir}
# Out:
# Title: QMC Raw Data for Superfulid Helium Adsorbed on Strained Graphene
# Keywords: Quantum Monte Carlo
# Publication date: 2022-11-01
# DOI: 10.5281/zenodo.7271852
# Total size: 1404.3 MB
#
# Link: https://zenodo.org/api/files/17865a21-b446-4451-a78e-8f53261cebe0/lindenset.zip   size: 2.6 MB
# 100% [......................................................] 2684284 / 2684284
# Checksum is correct. (56ac6129176613c49b330d6adeed1937)
#
# Link: https://zenodo.org/api/files/17865a21-b446-4451-a78e-8f53261cebe0/OUTPUT_largebox.zip   size: 12.9 MB
# ^C

# %%
qmc_data_dir = '../data/QMC/'

# %%
# !unzip {qmc_data_dir}lindenset.zip -d {qmc_data_dir}
# Out:
# Archive:  ../data/QMC/lindenset.zip
#    creating: ../data/QMC/lindenset/
#   inflating: ../data/QMC/lindenset/gce-estimator-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-lineardensity-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-log-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-planeavedensity-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-state-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-super-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-estimator-00.600-010.000--093.000-0.00313-ec9ecbb7-d08b-4d3c-948d-e6eb51465abb.dat
# ...

# %%
data_filenames = ['lindenset','OUTPUT_largebox','OUTPUT_phase','OUTPUT_T1set']
for data_filename in data_filenames:
    # !unzip -o {qmc_data_dir}{data_filename}.zip -d {qmc_data_dir}
# Out:
# Archive:  ../data/QMC/lindenset.zip
#    creating: ../data/QMC/lindenset/
#   inflating: ../data/QMC/lindenset/gce-estimator-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-lineardensity-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-log-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-planeavedensity-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-state-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-super-00.600-010.000--093.000-0.00313-ba589a73-9adf-4054-a0a2-1bb92ede3fdf.dat
#   inflating: ../data/QMC/lindenset/gce-estimator-00.600-010.000--093.000-0.00313-ec9ecbb7-d08b-4d3c-948d-e6eb51465abb.dat
# ...
